# %% [markdown]
# # Plant Disease classification

# %% [markdown]
# In this notebook, I will explore the diseased plant dataset to see what steps to take when I make my visual transformer. The dataset consists of nearly 3 gigabytes of images of diseased and healthy plants

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("vipoooool/new-plant-diseases-dataset")

print("Path to dataset files:", path)
# Out:
# ...
#  94%|█████████████████████████████████████████████████████████████████████████▏    | 2.53G/2.70G [11:17<03:25, 861kB/s]
